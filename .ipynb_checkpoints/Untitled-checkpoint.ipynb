# %%
# !pip3 list
# Out:
# Package                      Version
# ---------------------------- -----------
# 2ping                        4.5
# absl-py                      1.4.0
# anyio                        3.6.2
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.2.3
# asttokens                    2.2.1
# astunparse                   1.6.3
# attrs                        22.2.0
# Babel                        2.11.0
# backcall                     0.2.0
# bcrypt                       3.2.0
# beautifulsoup4               4.11.1
# bleach                       5.0.1
# blinker                      1.4
# branca                       0.6.0
# Brlapi                       0.8.4
# cachetools                   5.2.1
# catboost                     1.1.1
# certifi                      2022.6.15
# cffi                         1.15.1
# chardet                      4.0.0
# charset-normalizer           2.1.1
# click                        8.0.3
# ...

# %%
# !echo "hpcap" > scp * hpcap@192.168.82.72:Public
